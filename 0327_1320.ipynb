# %%
# !pip install datasets==1.18.3
# !pip install transformers==4.11.3
# !pip install  huggingface_hub==0.1
# !pip install torchaudio
# !pip install librosa
# !pip install jiwer
# Out:
# Requirement already satisfied: datasets==1.18.3 in /usr/local/lib/python3.7/dist-packages (1.18.3)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (2022.2.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (4.63.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (3.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (3.8.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (0.70.12.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (1.21.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (0.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (4.11.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (0.3.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (2.23.0)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.18.3) (6.0.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (3.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.18.3) (3.0.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.18.3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.18.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.18.3) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.18.3) (1.24.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (21.4.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.18.3) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets==1.18.3) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.18.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.18.3) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.18.3) (1.15.0)
# Requirement already satisfied: transformers==4.11.3 in /usr/local/lib/python3.7/dist-packages (4.11.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (0.0.49)
# Requirement already satisfied: huggingface-hub>=0.0.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (0.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (4.63.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (1.21.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (4.11.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (2019.12.20)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (6.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (0.10.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.11.3) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.17->transformers==4.11.3) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.11.3) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.11.3) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.11.3) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.11.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.11.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.11.3) (2.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.11.3) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.11.3) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.11.3) (7.1.2)
# Requirement already satisfied: huggingface_hub==0.1 in /usr/local/lib/python3.7/dist-packages (0.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface_hub==0.1) (3.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface_hub==0.1) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface_hub==0.1) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from huggingface_hub==0.1) (4.63.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface_hub==0.1) (4.11.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface_hub==0.1) (6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface_hub==0.1) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface_hub==0.1) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface_hub==0.1) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub==0.1) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub==0.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub==0.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub==0.1) (1.24.3)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (0.10.0+cu111)
# Requirement already satisfied: torch==1.10.0 in /usr/local/lib/python3.7/dist-packages (from torchaudio) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.0->torchaudio) (3.10.0.2)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.21.5)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.7)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: jiwer in /usr/local/lib/python3.7/dist-packages (2.3.0)
# Requirement already satisfied: python-Levenshtein==0.12.2 in /usr/local/lib/python3.7/dist-packages (from jiwer) (0.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein==0.12.2->jiwer) (57.4.0)

# %%
# path | text
# /content/drive/MyDrive/2022 논문/6_12.xlsx

# %%
import os
os.makedirs("/content/drive/MyDrive/2022_MA/json_files/6_12", exist_ok=True)

# %%
os.makedirs("/content/drive/MyDrive/2022_MA/json_files/6_22", exist_ok=True)

os.makedirs("/content/drive/MyDrive/2022_MA/json_files/7_12", exist_ok=True)
os.makedirs("/content/drive/MyDrive/2022_MA/json_files/7_22", exist_ok=True)

# %%
import pandas as pd
import json

dt_6_12 = pd.read_excel("/content/drive/MyDrive/2022_MA/txt_files/6_12_20s.xlsx", header=0, index_col=0)

dt_6_22 = pd.read_excel("/content/drive/MyDrive/2022_MA/txt_files/6_22_15s.xlsx", header=0, index_col=0)

dt_7_12 = pd.read_excel("/content/drive/MyDrive/2022_MA/txt_files/7_12_12s.xlsx", header=0, index_col=0)

dt_7_22 = pd.read_excel("/content/drive/MyDrive/2022_MA/txt_files/7_22_8s.xlsx", header=0, index_col=0)

# %%
# dt_6_12 파일 path 수정해야함
lst = []
for i in range(111): 
  lst.append(f"/content/drive/MyDrive/2022_MA/wav_files/6_12/chunk-{i}.wav")

dt_6_12['path'] = lst

# %%
for i in [dt_6_12, dt_6_22, dt_7_12, dt_7_22]:
  sum = 0
  sum += i.isnull().sum()
  print(sum)  # 7_12 문제있군 !
# Out:
# path    0
# text    0
# dtype: int64
# path    0
# text    0
# dtype: int64
# path      0
# text    209
# dtype: int64
# path    0
# text    0
# dtype: int64

# %%
dt_7_12.dropna(inplace=True)

# %%
for i in [dt_6_12, dt_6_22, dt_7_12, dt_7_22]:
  sum = 0
  sum += i.isnull().sum()
  print(sum)
# Out:
# path    0
# text    0
# dtype: int64
# path    0
# text    0
# dtype: int64
# path    0
# text    0
# dtype: int64
# path    0
# text    0
# dtype: int64

# %%
def to_json(dt):
  my_data = dt.to_dict(orient="records")
  #os.makedirs(f"/content/drive/MyDrive/2022_MA/json_files/{dt}")
  for i, sample in enumerate(my_data):
    with open("/content/drive/MyDrive/2022_MA/json_files/"+dt+f"/{i}.json", "w") as outfile:
      json.dump(sample, outfile, ensure_ascii=False)

# %%
dt = dt_6_12.to_dict(orient="records")
for i, sample in enumerate(dt):
  with open(f"/content/drive/MyDrive/2022_MA/json_files/6_12/{i}.json", "w") as outfile:
    json.dump(sample, outfile, ensure_ascii=False)

# %%
dt = dt_6_22.to_dict(orient="records")
for i, sample in enumerate(dt):
  with open(f"/content/drive/MyDrive/2022_MA/json_files/6_22/{i}.json", "w") as outfile:
    json.dump(sample, outfile, ensure_ascii=False)

# %%
dt = dt_7_12.to_dict(orient="records")
for i, sample in enumerate(dt):
  with open(f"/content/drive/MyDrive/2022_MA/json_files/7_12/{i}.json", "w") as outfile:
    json.dump(sample, outfile, ensure_ascii=False)

# %%
dt = dt_7_22.to_dict(orient="records")
for i, sample in enumerate(dt):
  with open(f"/content/drive/MyDrive/2022_MA/json_files/7_22/{i}.json", "w") as outfile:
    json.dump(sample, outfile, ensure_ascii=False)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.63.0)

# %%
len(os.listdir("/content/drive/MyDrive/2022_MA/json_files/6_12"))
# Out:
# 111

# %%
print(len(os.listdir("/content/drive/MyDrive/2022_MA/json_files/6_12")),
    len(os.listdir("/content/drive/MyDrive/2022_MA/json_files/6_22")),
      len(os.listdir("/content/drive/MyDrive/2022_MA/json_files/7_12")),
      len(os.listdir("/content/drive/MyDrive/2022_MA/json_files/7_22")))
# 20 15 12 8 seconds
# Out:
# 111 241 101 259

# %%
from datasets import load_dataset, load_metric, ClassLabel
import random 
import re

# /content/drive/MyDrive/2022_MA/json_files/6_12/0.json
d1 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/6_12/{i}.json" for i in range(100)], split="train")
# Out:
# Resolving data files:   0%|          | 0/100 [00:00<?, ?it/s]
# Using custom data configuration default-622a66c77b96e5f9
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-622a66c77b96e5f9/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-622a66c77b96e5f9/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.

# %%
import datasets

d2 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/6_22/{i}.json" for i in range(200)], split="train")
d3 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/7_12/{i}.json" for i in range(100)], split="train")
d4 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/7_22/{i}.json" for i in range(200)], split="train")


d_1 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/6_22/{i}.json" for i in range(100, 111)], split="train")
d_2 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/6_22/{i}.json" for i in range(200, 241)], split="train")
d_3 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/7_12/{i}.json" for i in range(100, 101)], split="train")
d_4 = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/7_22/{i}.json" for i in range(200, 259)], split="train")
# Out:
# Resolving data files:   0%|          | 0/200 [00:00<?, ?it/s]
# Using custom data configuration default-7e5d7fecbac724bb
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-7e5d7fecbac724bb/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-7e5d7fecbac724bb/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/100 [00:00<?, ?it/s]
# Using custom data configuration default-aeadea111c2bf050
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-aeadea111c2bf050/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-aeadea111c2bf050/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/200 [00:00<?, ?it/s]
# Using custom data configuration default-11c3bd246b380a20
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-11c3bd246b380a20/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-11c3bd246b380a20/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Using custom data configuration default-8d1b952ffad3e8a2
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-8d1b952ffad3e8a2/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-8d1b952ffad3e8a2/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/41 [00:00<?, ?it/s]
# Using custom data configuration default-f1b013e10a9288b0
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-f1b013e10a9288b0/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-f1b013e10a9288b0/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Using custom data configuration default-71c11bf8bcdbec50
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-71c11bf8bcdbec50/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-71c11bf8bcdbec50/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/59 [00:00<?, ?it/s]
# Using custom data configuration default-5453f8b4e93a3cae
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-5453f8b4e93a3cae/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-5453f8b4e93a3cae/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.

# %%
bbung_tr = datasets.concatenate_datasets([d1, d2, d3, d4, d1, d2, d3, d4, d1, d2, d3, d4, d1, d2, d3, d4, d1, d2, d3, d4, d1, d2, d3, d4,d1, d2, d3, d4,d1, d2, d3, d4])
bbung_te = datasets.concatenate_datasets([d_1, d_2, d_3, d_4,d_1, d_2, d_3, d_4,d_1, d_2, d_3, d_4,d_1, d_2, d_3, d_4])

# %%
train_dataset = bbung_tr 
test_dataset = bbung_te

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=5):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)

    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

show_random_elements(train_dataset.remove_columns(["path"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>어 이 퍼블릭 굳 게임 상황에 우리가 에프에스 모형을 적용을 해 보면 이렇게 컨트리뷰션이 얼마나 차이나느냐에 따라서 엔비를 느</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>그래서 이 사람 입장에서는 지금 코스트가 어 일부를 이제 어 저기 일부를 어 그 퍼블릭</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>일만큼 작아진다는 거잖아요 그쵸 내가 일원을 공공재를 위해 내놓지 않고 그냥 내가 먹는다는거는 이 쥐아이라는게 일만큼 작아진다는거고 그럼 그거로 인해서 나의 페이오프</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>그냥 자기가 먹는거를 더 선호한다 이제 그런 가정이예요 알이 일보다 작다는거는 자 그래서 어 마지막으로 한 번 정리를 하고 넘어가면 자 여기 녹색 형광펜 부분 알이 일보다 작</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>가 첫 번째 개인도 그렇고 두 번째 개인도 그렇고 모두가 영원을 내어놓는 그래서 공공재 생산을 위해서 자발적으로 돈을 내어놓는 사람이</td>
#     </tr>
#   </tbody>
# </table>

# %%
# d_train = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/6_12_chunk-{i}.json" for i in range(91)], split="train")
# d_test = load_dataset("json", data_files=[f"/content/drive/MyDrive/2022_MA/json_files/6_12_chunk-{i}.json" for i in range(91, 111)], split="train")

chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\_\(\)\{\}\[\]\&]' # 데이터 만들 때 사용한 문장 부호가 별로 없음

def remove_special_characters(batch):
  batch["text"] =re.sub(chars_to_ignore_regex, '', batch["text"])+" "
  return batch

c_voice_train = train_dataset.map(remove_special_characters)
c_voice_test = test_dataset.map(remove_special_characters)
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

vocab_train = c_voice_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=c_voice_train.column_names)
vocab_test = c_voice_test.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=c_voice_test.column_names)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
#vocab_tr = d_tr.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=d_tr.column_names)

# %%
#vocab_te = d_te.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=d_te.column_names)

# %%
vocab_list = list(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0]))
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
print(vocab_dict)
# Out:
# {'꺼': 0, '을': 1, '벌': 2, '싶': 3, '탕': 4, '클': 5, '열': 6, '랜': 7, '른': 8, '밉': 9, '드': 10, '무': 11, '용': 12, '저': 13, '뉘': 14, '올': 15, '왼': 16, '값': 17, '역': 18, '르': 19, '전': 20, '해': 21, '진': 22, '느': 23, '사': 24, '떼': 25, '내': 26, '5': 27, '6': 28, '히': 29, '룹': 30, '쉽': 31, '쳤': 32, '쪽': 33, '효': 34, '생': 35, '텍': 36, '펴': 37, '타': 38, '퓨': 39, '써': 40, '놈': 41, '럴': 42, ' ': 43, '학': 44, '설': 45, '떨': 46, '맏': 47, '치': 48, '념': 49, '알': 50, '씬': 51, '왠': 52, '뭐': 53, '씨': 54, '줘': 55, '갔': 56, '번': 57, '참': 58, '퍼': 59, '것': 60, '돼': 61, '낫': 62, '야': 63, '봤': 64, '담': 65, '색': 66, '빨': 67, '후': 68, '쓸': 69, '쌍': 70, '등': 71, '보': 72, '때': 73, '금': 74, '받': 75, '줍': 76, '살': 77, '분': 78, '까': 79, '관': 80, '닌': 81, '슷': 82, '재': 83, '총': 84, '시': 85, '으': 86, '덜': 87, '적': 88, '샛': 89, '큰': 90, '흥': 91, '굉': 92, '천': 93, '꼭': 94, '절': 95, '웅': 96, '예': 97, '왜': 98, '신': 99, '향': 100, '법': 101, '류': 102, '딱': 103, '켜': 104, '작': 105, '약': 106, '변': 107, '묶': 108, '통': 109, '똑': 110, '꿀': 111, '걷': 112, '억': 113, '격': 114, '럼': 115, '존': 116, '서': 117, '덤': 118, '갈': 119, '렸': 120, '련': 121, '혀': 122, '꿨': 123, '기': 124, '여': 125, '를': 126, '매': 127, '씩': 128, '워': 129, '였': 130, '심': 131, '증': 132, '혼': 133, '흰': 134, '명': 135, '레': 136, '뷰': 137, '롷': 138, '급': 139, '졌': 140, '혹': 141, '켓': 142, '7': 143, '얻': 144, '가': 145, '듯': 146, '큐': 147, '척': 148, '긴': 149, '략': 150, '뿐': 151, '호': 152, '0': 153, '횟': 154, '텐': 155, '륙': 156, '딕': 157, '더': 158, '쪼': 159, '쩜': 160, '대': 161, '볼': 162, '반': 163, '릴': 164, '출': 165, '널': 166, '모': 167, '봅': 168, '큼': 169, '또': 170, '익': 171, '푸': 172, '빠': 173, '놓': 174, '떤': 175, '방': 176, '델': 177, '랑': 178, '충': 179, '폰': 180, '능': 181, '정': 182, '째': 183, '힘': 184, '년': 185, '찮': 186, '싫': 187, '라': 188, '랬': 189, '냥': 190, '먼': 191, '찬': 192, '픽': 193, '피': 194, '확': 195, '괴': 196, '상': 197, '한': 198, '만': 199, '커': 200, '성': 201, '딨': 202, '껴': 203, '밌': 204, '착': 205, '소': 206, '깝': 207, '표': 208, '우': 209, '겠': 210, '섹': 211, '텀': 212, '직': 213, '넣': 214, '람': 215, '당': 216, '물': 217, '잉': 218, '험': 219, '몇': 220, '엄': 221, '됐': 222, '록': 223, '래': 224, '특': 225, '자': 226, '음': 227, '미': 228, '춰': 229, '도': 230, '렇': 231, '패': 232, '하': 233, '점': 234, '떠': 235, '육': 236, '체': 237, '밑': 238, '브': 239, '연': 240, '건': 241, '활': 242, '몰': 243, '초': 244, '균': 245, '겨': 246, '극': 247, '막': 248, '백': 249, '부': 250, '면': 251, '낮': 252, '쉬': 253, '셉': 254, '각': 255, '컨': 256, '켕': 257, '님': 258, '난': 259, '디': 260, '애': 261, '화': 262, '꾸': 263, '훨': 264, '져': 265, '뒷': 266, '입': 267, '낸': 268, '쑤': 269, '첫': 270, '판': 271, '땐': 272, '뺀': 273, '준': 274, '엠': 275, '별': 276, '테': 277, '3': 278, '괜': 279, '쟁': 280, '근': 281, '았': 282, '센': 283, '산': 284, '엔': 285, '딩': 286, '된': 287, '울': 288, '누': 289, '답': 290, '멘': 291, '과': 292, '쩔': 293, '업': 294, '멈': 295, '동': 296, '황': 297, '좀': 298, '믿': 299, '강': 300, '항': 301, '는': 302, '없': 303, '얘': 304, '쟤': 305, '짓': 306, '간': 307, '걸': 308, '옹': 309, '듣': 310, '첨': 311, '팔': 312, '발': 313, '론': 314, '추': 315, '식': 316, '짜': 317, '캔': 318, '키': 319, '투': 320, '택': 321, '세': 322, '말': 323, '글': 324, '냐': 325, '불': 326, '러': 327, '얼': 328, '되': 329, '다': 330, '개': 331, '놔': 332, '랄': 333, '찰': 334, '퀄': 335, '구': 336, '운': 337, '뭔': 338, '뻔': 339, '협': 340, '플': 341, '본': 342, '냈': 343, '삼': 344, '일': 345, '남': 346, '속': 347, '팀': 348, '많': 349, '뭘': 350, '슨': 351, '쵸': 352, '썼': 353, '군': 354, '완': 355, '박': 356, '집': 357, '형': 358, '헷': 359, '데': 360, '길': 361, '떻': 362, '펜': 363, '희': 364, '풀': 365, '배': 366, '눠': 367, '새': 368, '인': 369, '꾼': 370, '토': 371, '쓰': 372, '니': 373, '버': 374, '양': 375, '깐': 376, '스': 377, '루': 378, '들': 379, '고': 380, '둘': 381, '률': 382, '단': 383, '계': 384, '못': 385, '너': 386, '맞': 387, '든': 388, '영': 389, '엑': 390, '력': 391, '좋': 392, '문': 393, '링': 394, '아': 395, '닝': 396, '의': 397, '언': 398, '태': 399, '할': 400, '될': 401, '려': 402, '페': 403, '블': 404, '찾': 405, '감': 406, '교': 407, '왔': 408, '온': 409, '장': 410, ...

# %%
#vocab_dict = {v:k for k, v in enumerate(sorted(vocab_list))}

# %%
#len(vocab_dict)

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)

print(len(vocab_dict))
# Out:
# 587

# %%
#len(vocab_dict)

# %%
with open("/content/drive/MyDrive/2022_MA/vocab.json", "w") as vocab_file:
  json.dump(vocab_dict, vocab_file, ensure_ascii=False)

# %%
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2Processor, Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer.from_pretrained("/content/drive/MyDrive/2022_MA/", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")
# Out:
# file /content/drive/MyDrive/2022_MA/config.json not found
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
feature_extractor = Wav2Vec2FeatureExtractor(figure_size=1, sampling_rate=16000, padding_value=0.0, de_normalize=True, return_attention_mask=True)
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %%
import torchaudio 
import librosa
import numpy as np
from datasets import Audio

def audio_col_generate(batch):
  ar, sr = torchaudio.load(batch["path"])
  nar = ar[0].numpy()
  output = {}
  output["array"] = nar.astype('float32')
  output["path"] = batch["path"]
  output["sampling_rate"] = sr
  return {'audio': output}

# %%
d_tr_audio = c_voice_train.map(audio_col_generate)
d_te_audio = c_voice_test.map(audio_col_generate)
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
d_tr_audio
# Out:
# Dataset({
#     features: ['path', 'text', 'audio'],
#     num_rows: 4800
# })

# %%
def audio_resample(batch):
  batch["audio"]["array"] = librosa.resample(np.array(batch["audio"]["array"]), 44_100, 16_000)
  batch["audio"]["sampling_rate"] = 16_000
  return batch

# %%
rsp_d_tr_audio = d_tr_audio.map(audio_resample, num_proc=4)
rsp_d_te_audio = d_te_audio.map(audio_resample, num_proc=4)

# %%
def prepare_dataset(batch):
  audio = batch["audio"] 
  batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
  batch["input_length"] = len(batch["input_values"])

  with processor.as_target_processor():
    batch["labels"] = processor(batch["text"]).input_ids
  return batch

# %%
v_train = rsp_d_tr_audio.map(prepare_dataset, remove_columns=rsp_d_tr_audio.column_names)
v_test = rsp_d_te_audio.map(prepare_dataset, remove_columns=rsp_d_te_audio.column_names)
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
# !pip install dataclasses
# !pip install typing

# %%
import torch
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
  processor: Wav2Vec2Processor
  padding: Union[bool, str] = True

  def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
    input_features = [{"input_values": feature["input_values"]} for feature in features]
    label_features = [{"input_ids": feature["labels"]} for feature in features]

    batch = self.processor.pad(
        input_features,
        padding = self.padding,
        return_tensors = "pt",
    )

    with self.processor.as_target_processor():
      labels_batch = self.processor.pad(
          label_features,
          padding = self.padding,
          return_tensors = "pt",
      )

    labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

    batch["labels"] = labels

    return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
cer_metric = load_metric("cer")
wer_metric = load_metric("wer")

# %%
def compute_metrics(pred):
  pred_logits = pred.predictions
  pred_ids = np.argmax(pred_logits, axis=-1)

  pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

  pred_str = processor.batch_decode(pred_ids)

  label_str = processor.batch_decode(pred.label_ids, group_tokens=False)
  cer = cer_metric.compute(predictions = pred_str, references=label_str)
  #wer = wer_metric.compute(predictions=pred_str, references =label_str)

  return {"cer": cer}

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-xls-r-300m",
    attention_dropout = 0.0,
    hidden_dropout = 0.0,
    feat_proj_dropout = 0.0,
    mask_time_prob = 0.05,
    layerdrop = 0.0,
    ctc_loss_reduction = "mean",
    pad_token_id = processor.tokenizer.pad_token_id,
    vocab_size = len(processor.tokenizer),
)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-xls-r-300m were not used when initializing Wav2Vec2ForCTC: ['project_q.weight', 'quantizer.weight_proj.weight', 'project_q.bias', 'quantizer.codevectors', 'project_hid.weight', 'project_hid.bias', 'quantizer.weight_proj.bias']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-xls-r-300m and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_extractor()

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir = "/content/drive/MyDrive/2022_MA/xlsr-0327",
    group_by_length = True,
    per_device_train_batch_size = 16, 
    gradient_accumulation_steps = 2,
    evaluation_strategy = "steps",
    num_train_epochs = 30,
    gradient_checkpointing = True,
    fp16 = True,
    save_steps = 400, 
    eval_steps = 400, 
    logging_steps = 400, 
    learning_rate = 3e-4,
    warmup_steps = 500,
    save_total_limit = 2,
    load_best_model_at_end = True,
)

# %%
from transformers import Trainer 

trainer = Trainer(
    model = model,
    data_collator = data_collator,
    args = training_args,
    compute_metrics = compute_metrics, 
    train_dataset = v_train,
    eval_dataset = v_test,
    tokenizer = processor.feature_extractor,
)
# Out:
# Using amp fp16 backend

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length.
# ***** Running training *****
#   Num examples = 4800
#   Num Epochs = 30
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 2
#   Total optimization steps = 4500
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:158: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
#     <div>
#
#       <progress value='1511' max='4500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1511/4500 5:48:19 < 11:29:57, 0.07 it/s, Epoch 10.07/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>400</td>
#       <td>13.382800</td>
#       <td>4.376532</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>3.382100</td>
#       <td>1.292239</td>
#       <td>0.279946</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.809600</td>
#       <td>1.166743</td>
#       <td>0.205081</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length.
# ***** Running Evaluation *****
#   Num examples = 448
#   Batch size = 8
# Saving model checkpoint to /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-400
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-400/config.json
# Model weights saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-400/pytorch_model.bin
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-400/preprocessor_config.json
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length.
# ***** Running Evaluation *****
#   Num examples = 448
#   Batch size = 8
# Saving model checkpoint to /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-800
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-800/config.json
# Model weights saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-800/pytorch_model.bin
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-800/preprocessor_config.json
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length.
# ***** Running Evaluation *****
#   Num examples = 448
#   Batch size = 8
# Saving model checkpoint to /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/config.json
# Model weights saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/pytorch_model.bin
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/preprocessor_config.json
# Deleting older checkpoint [/content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-400] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-3435b262f1ae> in <module>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1314                         tr_loss_step = self.training_step(model, inputs)
#    1315                 else:
# -> 1316                     tr_loss_step = self.training_step(model, inputs)
#    1317
#    1318                 if (
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    1845         if self.use_amp:
#    1846             with autocast():
# -> 1847                 loss = self.compute_loss(model, inputs)
#    1848         else:
#    1849             loss = self.compute_loss(model, inputs)
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    1879         else:
#    1880             labels = None
# -> 1881         outputs = model(**inputs)
#    1882         # Save past state if it exists
#    1883         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in forward(self, input_values, attention_mask, output_attentions, output_hidden_states, return_dict, labels)
#    1497             output_attentions=output_attentions,
#    1498             output_hidden_states=output_hidden_states,
# -> 1499             return_dict=return_dict,
#    1500         )
#    1501
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in forward(self, input_values, attention_mask, mask_time_indices, output_attentions, output_hidden_states, return_dict)
#    1079             output_attentions=output_attentions,
#    1080             output_hidden_states=output_hidden_states,
# -> 1081             return_dict=return_dict,
#    1082         )
#    1083
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in forward(self, hidden_states, attention_mask, output_attentions, output_hidden_states, return_dict)
#     729                         create_custom_forward(layer),
#     730                         hidden_states,
# --> 731                         attention_mask,
#     732                     )
#     733                 else:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py in checkpoint(function, *args, **kwargs)
#     209         raise ValueError("Unexpected keyword arguments: " + ",".join(arg for arg in kwargs))
#     210
# --> 211     return CheckpointFunction.apply(function, preserve, *args)
#     212
#     213
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py in forward(ctx, run_function, preserve_rng_state, *args)
#      88
#      89         with torch.no_grad():
# ---> 90             outputs = run_function(*args)
#      91         return outputs
#      92
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in custom_forward(*inputs)
#     722                     def create_custom_forward(module):
#     723                         def custom_forward(*inputs):
# --> 724                             return module(*inputs, output_attentions)
#     725
#     726                         return custom_forward
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in forward(self, hidden_states, attention_mask, output_attentions)
#     569         hidden_states = self.layer_norm(hidden_states)
#     570         hidden_states, attn_weights, _ = self.attention(
# --> 571             hidden_states, attention_mask=attention_mask, output_attentions=output_attentions
#     572         )
#     573         hidden_states = self.dropout(hidden_states)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     488         attn_output = attn_output.reshape(bsz, tgt_len, embed_dim)
#     489
# --> 490         attn_output = self.out_proj(attn_output)
#     491
#     492         return attn_output, attn_weights_reshaped, past_key_value
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:

# %%
model.save_pretrained("/content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200")
processor.save_pretrained("/content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200")

model = Wav2Vec2ForCTC.from_pretrained("/content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200").to("cuda")
processor = Wav2Vec2Processor.from_pretrained("/content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200")
# Out:
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/config.json
# Model weights saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/pytorch_model.bin
# Configuration saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/preprocessor_config.json
# tokenizer config file saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/special_tokens_map.json
# added tokens file saved in /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/added_tokens.json
# loading configuration file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/config.json
# Model config Wav2Vec2Config {
#   "_name_or_path": "facebook/wav2vec2-xls-r-300m",
#   "activation_dropout": 0.0,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 768,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": true,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": false,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": true,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_dropout": 0.0,
#   "feat_extract_norm": "layer",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.0,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.0,
#   "mask_feature_length": 10,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_prob": 0.05,
#   "model_type": "wav2vec2",
#   "num_attention_heads": 16,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 24,
#   "num_negatives": 100,
#   "pad_token_id": 586,
#   "proj_codevector_dim": 768,
#   "torch_dtype": "float32",
#   "transformers_version": "4.11.3",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 589
# }
#
# loading weights file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/pytorch_model.bin
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.
# loading feature extractor configuration file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/preprocessor_config.json
# Feature extractor Wav2Vec2FeatureExtractor {
#   "de_normalize": true,
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "figure_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": true,
#   "sampling_rate": 16000
# }
#
# Didn't find file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/tokenizer.json. We won't load it.
# loading file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/vocab.json
# loading file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/tokenizer_config.json
# loading file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/added_tokens.json
# loading file /content/drive/MyDrive/2022_MA/xlsr-0327/checkpoint-1200/special_tokens_map.json
# loading file None
# Adding <s> to the vocabulary
# Adding </s> to the vocabulary

# %%
def check_perf(n):
  input_dict = processor(v_test["input_values"][n], sampling_rate=16000, return_tensors="pt", padding=True)
  logits = model(input_dict.input_values.to("cuda")).logits
  pred_ids = torch.argmax(logits, dim=-1)[0]

  print("P:", processor.decode(pred_ids))
  print("R:", processor.decode(v_test["labels"][n]))

# %%
for i in range(3, 6):
  print(check_perf(i))
# Out:
# P: 그럼 삼번 개인도 알만큼 얻고 사번 오번 엔번 개인도 알만큼 얻게 되겠죠 베네핏을 공공재의 정의에 의해서 그래서 지금 일번 개인이 일원만큼 공공재 공급을 위해서
# R: 그럼 삼번 개인도 알만큼 얻고 사번 오번 엔번 개인도 알만큼 얻게 되겠죠 베네핏을 공재의 정의에 의해서 그래서 지금 일번 개인이 일원만큼 공재 공급을 위해서
# None
# P: 돈을 내어 놓으면 일번 개인 뿐만 아니고 모두가 알만큼의 베너핏을 얻게되요 그러면 총 베너핏은 얼마죠 이걸 다 더해보면 총 베너핏은 이제 알 곱하기
# R: 돈을 내어 놓으면 일번 개인 뿐만 아니고 모두가 알만큼의 베너핏을 얻게되요 그러면 총 베너핏은 얼마죠 이걸 다 더해보면 총 베너핏은 이제 알 곱하기
# None
# P: 엔이겠죠 그래서 이게 공공재 생산을 통해서 어 이 사회에서 얻게되는 총 베너핏 혹은 총 페이오프예요 그래서 일번 개인이 일원 만큼만
# R: 엔이겠죠 그래서 이게 공재 생산을 통해서 어 이 사회에서 얻게되는 총 베너핏 혹은 총 페이오프예요 그래서 일번 개인이 일원 만큼만
# None

# %%
v_test
# Out:
# Dataset({
#     features: ['input_values', 'input_length', 'labels'],
#     num_rows: 448
# })

# %%
for i in range(50, 100):
  print(check_perf(i))
# Out:
# P: 우가 스탠다드 모형으로는 전 설명을 할수가 없는 부분이고 그래서 우리가 이 프에스 모형을 가지고 한 번 생각을 해볼 필효가 있겠죠 그래서 이 영상에서는 우리가 퍼블릭굳 게임이라는
# R: 우리가 스탠다드 모형으로는 전혀 설명을 할 수 없는 부분이고 그래서 우리가 에프에스 모형을 가지고 한 번 생각을 해볼 필요가 있겠죠 그래서 이 영상에서는 우리가 어 퍼블릭 굳 게임이라는게
# None
# P: 어떤상황인지를 설명을 했고 그리고 스탠다드 모형으로는 설명의 대는 부분드 있지만 또 생함 부분 설명이에 안된는 부분들도 있더라 하는를 계습니다
# R: 어던 상황인지를 설명을 했고 그리고 스탠다드 모형으로는 설명이 되는 부분도 있지만 또 상당부분 설명이 안되는 부분도 있더라 라는 것을 배웠습니다
# None
# P: 프가 줄어드니까 내가 먹는게 줄어들어서내가 엔비가 더 커지겠죠 그쵸 그래서 내가 일불만큼을 퍼블릭 굳에 더 투자를 하면
# R: 프가 줄어드니까 내가 먹는게 줄어들어서 내가 엔비가 더 커지겠죠 그쵸 그래서 내가 일불 만큼을 내가 퍼블릭굳에 더 투자를 하면
# None
# P: 이아이디어를 가지고 막 그래을 여기서 의 가서 막 다 육 했어 그래서
# R: 이 아이디어를 가지고 막 별의별 어 여기저기 가서 막 다 했어 그래서
# None
# P: 무슨뭐 선진구에서도 하고 계발에 더도 상국게 수도 이런 실험 해보가 막했거으요 그래서 이제
# R: 무슨 뭐 그 선진국에서도 하고 개발도상국에서도 이런 실험을 해보고 했거든요 그래서 이제
# None
# P: 어 천진구에서는 예를 들어서 뭐 좀 적은도 니라고 하더라도 그게 개발 좋산을
# R: 어 선진국에서는 예를 들어서 좀 적은 돈이라고 하더라도 그게 개발도상국
# None
# P: 구에서는 굉장히 큰동 수 있죠 그래서 그런식으로 해서 이제 개발 또좋산구에서는 굉장히 큰금에기 수 있는 그런금면
# R: 국에서는 굉장히 큰 돈일 수 있죠 그래서 그런 식으로 해서 개발도상국에서는 굉장히 큰 금액일 수 있는 그런 금액
# None
# P: 또 걸고 비한 실험을 했어도 이러한한 베타는 비하게 나온다는거 그래서
# R: 액도 걸고 비슷한 실험을 했어도 이러한 패턴은 비슷하게 나온다는거지 그래서
# None
# P: 걸려있는 금명이 굉장히 크다고 하더라도 뭐 걸려있는 거에 있굉장히 크면 사람들이 거짓말을 좀더 많이 할 수 있겠죠 그러 그렇지만큼
# R: 걸려있는 금액이 굉장히 크다고 하더라도 뭐 걸려있는 금액이 굉장히 크면 사람들이 거짓말을 조금 더 많이 할 수는 있겠죠 그러면 그렇지만 그런
# None
# P: 에드 불구하고 여전히  정직하게 이야기하한 사람들이 있더라 라는거야 그래서 이제 마지막
# R: 그럼에도 불구하고 여전히 정직하게 이야기하는 사람들이 있더라 라는 거예요 그래서 이제 마지막으로
# None
# P: 로 뭐 생각을 해볼 수 있는거는  그러 스탠다드 모형으로 우리가 설명하지 못하는 부분들이 있다 사람들이 정직하다라는거죠 사람들에
# R: 로 뭐 생각을 해볼 수 있는거는 자 그럼 스탠다드 모형으로 우리가 설명하지 못하는 부분들이 있다 사람들이 정직하다라는거죠 사람들은 왜
# None
# P: 정직하냐 구어가면요 확연히 사람이 정직크의 사람드니 까 정직하게 이야기해야줘이렇게 이얘기은 할말이없어
# R: 왜 정직하냐 그러면 당연히 사람이 정직하게 살아야되니까 정직하게 이야기해야죠 뭐 이렇게 이야기하면 할 말이 없죠
# None
# P: 이 고렇게 이야기하면는 이제 뭐 할말이는데 자 이제 뭐 경제학적으로 이야기할려면
# R: 이제 고롷게 이야기하면 이제 뭐 할 말이 없는데 자 이제 뭐 경제학적으로 이야기할려면
# None
# P: 동같 좀 사람들이 이센티브 어떤 센트브가 있긴낸 사람들이 정직하게 이야기할까 이런 이야기를 했야되잖아겠쵸 그래서 우리가 첫번째
# R: 면 뭔가 좀 사람들이 인센티브 어떤 인센티브가 있길래 사람들이 정직하게 이야기할까 이런 이야기를 해야되잖아 그쵸 그래서 우리가 첫 번째
# None
# P: 얘기할 수 있는거는 라잉 코스트라고가할까 이런게 있된거지 그래서 예를 들어서 어떤 사람의 효용 한수해 보면
# R: 이야기할 수 있는거는 어떤 라인코스트라고 할까 이런게 있는거지 그래서 예를 들어서 어떤 사람의 효용 함수에 보면
# None
# P: 결용 합 세 보면 이제 돈이 많으면은 당연히 이제 돈이 만으면 당연히 이제 대 효의 높아지는데
# R: 효옹 함수에 보면 이제 돈이 많으면은 당연히 이제 돈이 많으면 당연히 이제 내 효용이 높아지는데
# None
# P: 마이너스로 뭐가들어고냐 하면 이제 거짓말 했을때그서 예를 들어서 무슨보갈까요  뭐
# R: 마이너스로 뭐가 들어오냐하면 이제 거짓말 했을 때 그래서 예를 들어서 무슨 뭐라고할까요 뭐 뭐 무슨
# None
# P: 뭐 알파라는게 있어가지고 여기에 있인지 거짓말의 크기 예를 들어서
# R: 뭐 알파라는게 있어가지고 여기에 이제 거짓말의 크기 예를 들어서
# None
# P: 그래서 내가 내가 한 거짓말의 큰크기해 따라서 코 스
# R: 그래서 내가 내가 한 거짓말의 크기에 따라서 코스트
# None
# P: 스트가 발생을 하는거지 알파만큼 예를 들어서 그 내가 거짓말을 조금했으 예를어서 내가 거짓말을 뭐 예어서 영점 일 만큼했어 그담 이
# R: 트가 발생을 하는거지 알파만큼 예를 들어서 그래서 내가 거짓말을 조금 했음 예를 들어서 내가 거짓말을 영점 일 만큼 했어 그러면
# None
# P: 면라인코스트를 통에서 내 효용이 마이너스 영점 일 곱하기 알파 만큼의 효용이 줄어들어 안아 거짓을 했구나
# R: 면 라인코스트를 통해서 내 효용이 마이너스 영점 일 곱하기 알파 만큼 효용이 줄어들어 아 내가 거짓말 했구나
# None
# P: 아참나는 여시 안는데 나분놓이야 이러면 서 번 자기가 예를 들어서 그런걸로 이제 비효용이 발생을 하는거지
# R: 아 참 나는 역시 안돼 나쁜놈이야 이러면서 뭐 자괴감 예를 들어서 그런 걸로 이제 비효용이 발생을 하는거지
# None
# P: 그리고 거짓말 략굉 크게 했어 예를 들어서 뭐 거짓말을 굉장 수겠어 예를 들어서 내가 아이프가오
# R: 그리고 거짓말을 내가 굉장히 크게 했어 예를 들어서 뭐 거짓말을 굉장히 크게 했어 예를 들어서 내가 아이큐가
# None
# P: 뭐여긴데 나 사실 마이 맨나 왼자 해어니야 굉장히 크게 내가 거짓말을 방쳐어 예를 들어서 그러면 그걸로부터
# R: 뭐 백인데 나 사실 뭐 멘사 회원이야 굉장히 크게 내가 거짓말을 뻥쳤어 예를 들어서 그러면은 그거로부터
# None
# P: 어 라인 코스트를 통에서 비효인 경 크게 발생을 하는거지 그래서 이러 사람들의
# R: 어 라인코스트를 통해서 비효용이 굉장히 크게 발생을 하는거지 그래서 이런 사람들의
# None
# P: 이 사람들의 선원에라잉 먹발전 혹은 라히 코스트라는 그런 텀이 있기 때문에 사람들이
# R: 사람들의 선호에 라인 어벌젼 혹은 라인코스트라는 그런 텀이 있기 때문에 사람들이
# None
# P: 그래도 거짓말을 좀 덜 하고 진실을 이야기하도하고 그런게 아니까 이런걸 생각을 해 볼 수가 있겠죠 그리고
# R: 그래도 거짓말을 좀 덜 하고 진실을 이야기하기도 하고 그런게 아닐까 요런거를 생각해 볼 수가 있겠죠 그리고
# None
# P: 도 사람들이 이제 나는 이늘마한 사람이야 라고 이제 스은별린을 하는거지
# R: 또 사람들이 이제 나는 믿을만한 사람이야 라고 시그널링을 하는거지
# None
# P: 그래서 이제 다른 사람한테 스걸린을 하는데 나는 이질마나 사람이야 그니까 이제
# R: 그래서 이제 다른 사람한테 시그널링을 하는데 나는 믿을만한 사람이야 그러니까 이제
# None
# P: 어나 나봐 나 지금 오천원 뭐를 수도 있는데 나 그걸 프기하고 자진실를 이야기했잖아 나 비늘마한 사람의 나좀 2어줘
# R: 나 봐 나 지금 오천원 먹을 수도 있는데 나 그거 포기하고 나 진실을 이야기했잖아 나 믿을 만한 사람이야 나 좀 믿어줘
# None
# P: 고 스간날린을 하는거죠 서 이렇게 시을린해서 어 내가 이들마너 사람이라는것을 다른 사람이이 생각 하게 때
# R: 하고 시그널링을 하는거죠 이렇게 요렇게 시그널링을 해서 내가 믿을만한 사람이라는것을 다른 사람이 생각하게 되면
# None
# P: 면 예를 들어서 나중의 나한테 뭐 좋을 수 있겠죠 그래 쓰 얼니만 그리고 또 예를 들어서 나는
# R: 면 예를 들어서 나중에 나한테 뭐 좋을 수 있겠죠 그래서 시그널링 하는거 그리고 또 예를 들어서 나는
# None
# P: 차프리 이지이 좋조게 가져가면 그걸로부터 내가 효용을 얻더 예를 들어서 그래서 내 효용 한수에
# R: 셀프 이미지를 이제 좋게 가져가면 그걸로부터 내가 효용을 얻어 예를 들어서 그래서 내 효용함수에
# None
# P: 이제 예를 들어서 내효용남 수요뭐 돈 뿐만 아니고 검가 나 자신에대하눠더 이미지라는거를
# R: 이제 예를 들어서 내 효용 함수에 뭐 돈 뿐만 아니고 먼가 나 자신에 대한 이미지라는거를
# None
# P: 이제 내 효용 함에 들어는거예요 그래서 이거를 숫자로 이야기하기는 뭐 싶지안을 수도 있지만 그래에서 뭐 정식
# R: 이제 내 효용함수에 들어오는거야 그래서 이거를 숫자로 이야기하기는 쉽지 않을 수 있지만 점수
# None
# P: 만에 전수로 관산네서 생각 할 수가 있겠죠 나와야대한 이이 지 이 영에서 백 예를 들어서 그래서 나의 이미지가 영이다 이건 스험
# R: 제로 점수로 환산해서 생각을 할 수가 있겠죠 나에 대한 이미지가 영에서 백 예를 들어서 그래서 나의 이미지가 영이다 이건 쓰레
# None
# P: 이지나 이미지가 베기다 이거는 천사 예를 들어서 그래서 나스수로 나자신에대한 이미지를 어떤
# R: 기 나의 이미지가 백이다 이거는 천사 예를 들어서 그래서 나 스로 나 자신에 대한 이미지를 어떤
# None
# P: 영에서 백간의 적득로 생각을 해서 그 숫자가 높클수록 아 나는 참 좋은 사람이 알 라고색 프 입이지를 가지 수 있고
# R: 영에서 백까지의 척도로 생각을 해서 그 숫자가 높을수록 아 나는 참 좋은 사람이야 라고 셀프 이미지를 가질 수 있고
# None
# P: 그걸로부터 예를 서 내가 자신감로 얻 얻는다고나 그런식으로 나야 나한테 효용이 발생 하는거죠
# R: 그걸로부터 예를 들어 내가 자신감을 얻는다거나 뭐 그런 식으로 나한테 효용이 발생 하는거죠
# None
# P: 그래서뭐 이한 이유유들 때문에 전통은경제학이 론이 생각할 수업는 사람이
# R: 그래서 뭐 이러한 이유들 때문에 어 전통 경제학 이론이 생각할 수 없는 사람들
# None
# P: 들이 이제 뭐 진실을 이야기하고 거짓말을 하면은 부명이 이득걸 볼 수 있으이등 불가고 거짓말 하지 않는 그러고 거짓말
# R: 들이 이제 뭐 진실을 이야기하고 거짓말을 하면은 분명히 이득을 볼 수 있음에도 불구하고 거짓말을 하지 않는 그리고 거짓말을
# None
# P: 하더라도 엄청거짓말 하지는 않고 조금 거짓말를 하는 뭐 그런 행동늘 포있는게 하니까  생각을 해
# R: 하더라도 엄청 거짓말을 하지는 않고 조금 거짓말을 하는 뭐 그런 행동들을 보이는게 아닐까 이제 생각을
# None
# P: 볼 수가 있겠죠 그래서 여기 이  이 강에서는 이 영상에서는 우리가
# R: 해 볼 수가 있겠죠 그래서 여기 어 이 어 이 강의에서는 이 영상에서는 우리가
# None
# P: 어  재미는 실험 난구가 한하나을 우리가 가이 살펴봤고 그래서 마지막으로 이제 한번도 산들에서 이야기면
# R: 어 이 재밌는 실험 연구 하나를 우리가 같이 살펴봤고 그래서 마지막으로 이제 한 번 더 강조해서 이야기하면
# None
# P: 면 이 실험 아이디어는 이제 결과를 보면 뭐 켕비은을 결과들이 있죠 근데 정말 중요한거는 뭐냐 이실험 아이디어 자체를
# R: 이 실험 아이디어는 이제 결과를 보면 뭐 흥미로운 결과들이 있죠 근데 정말 중요한거는 뭐냐면은 이 실험 아이디어 자체를
# None
# P: 이 실험 아이디어를 우리가 실제로 다양하한 그룹들의게 적용을 해 보고 그래서 다양한 그룹들가
# R: 이 실험 아이디어를 우리가 실제로 다양한 그룹들에게 적용을 해 보고 그래서 다양한 그룹들 간에
# None
# P: 자간에어떻게 아니스티가 모랄러티 차이가 있는지를 우실티로 측정을해볼 수 있다는게 이 사실이문에서 우리가 어을 수 있는
# R: 간에 어떻게 아니스티와 모랄러티의 차이가 있는지를 우리가 실제로 측정을 해 볼 수 있다는게 이 사실은 논문에서 얻을 수 있는
# None
# P: 지 와이돼죠 그래서 여러분들 이제 어 나중에 이제 시가 나면요
# R: 핵심 아이디어죠 그래서 여러분들 이제 나중에 이제 어 시간 나면
# None
# P: 이아이디어를 가지고 한번 해보세 주변에 그데 주변의 할때는 이제 그룹 나눠서 해봐야되겠지 그래서 뭐 나이로 나놓다고나
# R: 이 아이디어를 가지고 한 번 해보세요 주변에 그런데 주변에 할 때는 이제 그룹을 나눠서 해봐야되겠지 그래서 뭐 나이로 나눈다거나
# None
# P: 아니먼뭐 평별로 나는 나거나 한 4은 지역으로 나놓 다던가 예를 들어서 그래서 그룹을 나으고 그룹 사람들한테이제
# R: 아니면 뭐 성별로 나눈다거나 뭐 사는 지역으로 나눈다거나 예를 들어서 그래서 그룹을 나누고 그룹 사람들한테 이제
# None
